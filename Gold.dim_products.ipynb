# %%
query="""
select 
product_id,
product_key,
product_name,
catogeroy_id,
Catogeroy,
SubCatogeroy,
Maintenance,
Product_line,
Product_start_date
from silver.crm_products
left join workspace.silver.erp_product_category
WHERE product_end_date IS NULL;
"""
df=spark.sql(query)

# %%
df.display()

# %% [markdown]
# #Writing into gold layer

# %%
df.write.mode("overwrite").saveAsTable("gold.dim_products")

# %%
# %sql
select * from gold.dim_products
